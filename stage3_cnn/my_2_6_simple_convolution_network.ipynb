# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')

# %% [markdown]
# # simple convolution network

# %% [markdown]
# ## image to column

# %%
import pickle
import numpy as np
from collections import OrderedDict
from common import layers
from common import optimizer
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# 画像データを２次元配列に変換
'''
input_data: 入力値
filter_h: フィルターの高さ
filter_w: フィルターの横幅
stride: ストライド
pad: パディング
'''
def im2col(input_data, filter_h, filter_w, stride=1, pad=0):
    # N: number, C: channel, H: height, W: width
    N, C, H, W = input_data.shape
    out_h = (H + 2 * pad - filter_h)//stride + 1
    out_w = (W + 2 * pad - filter_w)//stride + 1

    img = np.pad(input_data, [(0,0), (0,0), (pad, pad), (pad, pad)], 'constant')
    col = np.zeros((N, C, filter_h, filter_w, out_h, out_w))

    for y in range(filter_h):
        y_max = y + stride * out_h
        for x in range(filter_w):
            x_max = x + stride * out_w
            col[:, :, y, x, :, :] = img[:, :, y:y_max:stride, x:x_max:stride]
    
    col = col.transpose(0, 4, 5, 1, 2, 3) # (N, C, filter_h, filter_w, out_h, out_w) -> (N, filter_w, out_h, out_w, C, filter_h)    
    
    col = col.reshape(N * out_h * out_w, -1)
    return col

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] im2colの処理を確認しよう
# ・関数内でtransposeの処理をしている行をコメントアウトして下のコードを実行してみよう<br>
# ・input_dataの各次元のサイズやフィルターサイズ・ストライド・パディングを変えてみよう
#
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# im2colの処理確認
input_data = np.random.rand(2, 3, 16, 16)*100//1 # number, channel, height, widthを表す
print('========== input_data ===========\n', input_data)
print('==============================')
filter_h = 4
filter_w = 4
stride = 2
pad = 0
col = im2col(input_data, filter_h=filter_h, filter_w=filter_w, stride=stride, pad=pad)
print('============= col ==============\n', col)
print('==============================')
# Out:
# ========== input_data ===========
#  [[[[45. 11. 78. ... 38. 12. 78.]
#    [28.  8. 96. ... 54. 80. 68.]
#    [70. 36. 24. ... 11. 22. 49.]
#    ...
#    [39. 13. 47. ... 75. 20. 83.]
#    [63. 37. 79. ... 67. 34.  3.]
#    [94. 62. 99. ...  2. 67. 32.]]
#
#   [[43. 52. 75. ... 21. 57. 41.]
#    [34. 58. 68. ... 85. 30. 22.]
#    [79. 61. 77. ... 21. 59. 42.]
#    ...
#    [44. 90. 26. ... 25. 46. 65.]
#    [37. 51.  9. ... 90. 80. 35.]
#    [37. 17. 35. ... 38. 34. 23.]]
#
#   [[13. 42. 91. ... 80. 35. 13.]
#    [74. 82. 20. ... 73. 60. 14.]
#    [97. 26. 77. ... 27.  1. 10.]
#    ...
#    [89. 64. 35. ...  2. 43. 39.]
#    [62. 84. 18. ...  4. 72.  9.]
#    [26. 55. 10. ... 40.  9.  3.]]]
#
#
#  [[[51. 73. 55. ... 59. 82.  7.]
#    [26. 38.  1. ... 50. 84.  2.]
#    [ 5. 45. 83. ...  1. 55. 32.]
#    ...
#    [17. 61. 29. ... 77. 27. 60.]
#    [26. 77. 66. ... 93. 84.  5.]
#    [76.  3. 17. ... 63. 86. 92.]]
#
#   [[23. 48. 27. ... 35. 37. 32.]
#    [98. 82. 75. ... 56. 12. 71.]
#    [51.  7. 59. ... 11. 90. 21.]
#    ...
#    [64. 48. 12. ... 80. 26. 59.]
#    [74. 84. 14. ... 98. 92. 94.]
#    [77. 82. 41. ... 63. 43. 78.]]
#
#   [[87. 39. 49. ... 22. 23. 48.]
#    [ 2. 89. 80. ... 52. 48. 13.]
#    [24. 34. 45. ...  2. 44. 21.]
#    ...
#    [20.  1. 12. ... 93. 87. 81.]
#    [23. 77. 37. ... 71. 37. 18.]
#    [47.  5. 22. ...  0. 37. 59.]]]]
# ==============================
# ============= col ==============
#  [[45. 11. 78. ... 83. 32. 85.]
#  [78.  9. 52. ... 85. 31. 37.]
#  [52. 88. 57. ... 37. 49. 57.]
#  ...
#  [52. 31. 52. ... 99. 18. 38.]
#  [52. 63. 23. ... 38. 43.  0.]
#  [23. 71. 84. ...  0. 37. 59.]]
# ==============================

# %% [markdown]
# ## column to image

# %%
# ２次元配列を画像データに変換
def col2im(col, input_shape, filter_h, filter_w, stride=1, pad=0):
    # N: number, C: channel, H: height, W: width
    N, C, H, W = input_shape
    # 切り捨て除算    
    out_h = (H + 2 * pad - filter_h)//stride + 1
    out_w = (W + 2 * pad - filter_w)//stride + 1
    col = col.reshape(N, out_h, out_w, C, filter_h, filter_w).transpose(0, 3, 4, 5, 1, 2) # (N, filter_h, filter_w, out_h, out_w, C)

    img = np.zeros((N, C, H + 2 * pad + stride - 1, W + 2 * pad + stride - 1))
    for y in range(filter_h):
        y_max = y + stride * out_h
        for x in range(filter_w):
            x_max = x + stride * out_w
            img[:, :, y:y_max:stride, x:x_max:stride] += col[:, :, y, x, :, :]

    return img[:, :, pad:H + pad, pad:W + pad]

# %% [markdown]
# ## [try] col2imの処理を確認しよう
# ・im2colの確認で出力したcolをimageに変換して確認しよう

# %%
img = col2im(col, input_data.shape, filter_h, filter_w, stride, pad)
print(img)
# Out:
# [[[[ 45.  11. 156. ...  76.  12.  78.]
#    [ 28.   8. 192. ... 108.  80.  68.]
#    [140.  72.  96. ...  44.  44.  98.]
#    ...
#    [ 78.  26. 188. ... 300.  40. 166.]
#    [ 63.  37. 158. ... 134.  34.   3.]
#    [ 94.  62. 198. ...   4.  67.  32.]]
#
#   [[ 43.  52. 150. ...  42.  57.  41.]
#    [ 34.  58. 136. ... 170.  30.  22.]
#    [158. 122. 308. ...  84. 118.  84.]
#    ...
#    [ 88. 180. 104. ... 100.  92. 130.]
#    [ 37.  51.  18. ... 180.  80.  35.]
#    [ 37.  17.  70. ...  76.  34.  23.]]
#
#   [[ 13.  42. 182. ... 160.  35.  13.]
#    [ 74.  82.  40. ... 146.  60.  14.]
#    [194.  52. 308. ... 108.   2.  20.]
#    ...
#    [178. 128. 140. ...   8.  86.  78.]
#    [ 62.  84.  36. ...   8.  72.   9.]
#    [ 26.  55.  20. ...  80.   9.   3.]]]
#
#
#  [[[ 51.  73. 110. ... 118.  82.   7.]
#    [ 26.  38.   2. ... 100.  84.   2.]
#    [ 10.  90. 332. ...   4. 110.  64.]
#    ...
#    [ 34. 122. 116. ... 308.  54. 120.]
#    [ 26.  77. 132. ... 186.  84.   5.]
#    [ 76.   3.  34. ... 126.  86.  92.]]
#
#   [[ 23.  48.  54. ...  70.  37.  32.]
#    [ 98.  82. 150. ... 112.  12.  71.]
#    [102.  14. 236. ...  44. 180.  42.]
#    ...
#    [128.  96.  48. ... 320.  52. 118.]
#    [ 74.  84.  28. ... 196.  92.  94.]
#    [ 77.  82.  82. ... 126.  43.  78.]]
#
#   [[ 87.  39.  98. ...  44.  23.  48.]
#    [  2.  89. 160. ... 104.  48.  13.]
#    [ 48.  68. 180. ...   8.  88.  42.]
#    ...
#    [ 40.   2.  48. ... 372. 174. 162.]
#    [ 23.  77.  74. ... 142.  37.  18.]
#    [ 47.   5.  44. ...   0.  37.  59.]]]]

# %% [markdown]
# ## convolution class

# %%
class Convolution:
    # W: フィルター, b: バイアス
    def __init__(self, W, b, stride=1, pad=0):
        self.W = W
        self.b = b
        self.stride = stride
        self.pad = pad
        
        # 中間データ（backward時に使用）
        self.x = None   
        self.col = None
        self.col_W = None
        
        # フィルター・バイアスパラメータの勾配
        self.dW = None
        self.db = None

    def forward(self, x):
        # FN: filter_number, C: channel, FH: filter_height, FW: filter_width
        FN, C, FH, FW = self.W.shape
        N, C, H, W = x.shape
        # 出力値のheight, width
        out_h = 1 + int((H + 2 * self.pad - FH) / self.stride)
        out_w = 1 + int((W + 2 * self.pad - FW) / self.stride)
        
        # xを行列に変換
        col = im2col(x, FH, FW, self.stride, self.pad)
        # フィルターをxに合わせた行列に変換
        col_W = self.W.reshape(FN, -1).T

        out = np.dot(col, col_W) + self.b
        # 計算のために変えた形式を戻す
        out = out.reshape(N, out_h, out_w, -1).transpose(0, 3, 1, 2)

        self.x = x
        self.col = col
        self.col_W = col_W

        return out

    def backward(self, dout):
        FN, C, FH, FW = self.W.shape
        dout = dout.transpose(0, 2, 3, 1).reshape(-1, FN)

        self.db = np.sum(dout, axis=0)
        self.dW = np.dot(self.col.T, dout)
        self.dW = self.dW.transpose(1, 0).reshape(FN, C, FH, FW)

        dcol = np.dot(dout, self.col_W.T)
        # dcolを画像データに変換
        dx = col2im(dcol, self.x.shape, FH, FW, self.stride, self.pad)

        return dx

# %% [markdown]
# ## pooling class

# %%
class Pooling:
    def __init__(self, pool_h, pool_w, stride=1, pad=0):
        self.pool_h = pool_h
        self.pool_w = pool_w
        self.stride = stride
        self.pad = pad
        
        self.x = None
        self.arg_max = None

    def forward(self, x):
        N, C, H, W = x.shape
        out_h = int(1 + (H - self.pool_h) / self.stride)
        out_w = int(1 + (W - self.pool_w) / self.stride)
        
        # xを行列に変換
        col = im2col(x, self.pool_h, self.pool_w, self.stride, self.pad)
        # プーリングのサイズに合わせてリサイズ
        col = col.reshape(-1, self.pool_h*self.pool_w)
        
        # 行ごとに最大値を求める
        arg_max = np.argmax(col, axis=1)
        out = np.max(col, axis=1)
        # 整形
        out = out.reshape(N, out_h, out_w, C).transpose(0, 3, 1, 2)

        self.x = x
        self.arg_max = arg_max

        return out

    def backward(self, dout):
        dout = dout.transpose(0, 2, 3, 1)
        
        pool_size = self.pool_h * self.pool_w
        dmax = np.zeros((dout.size, pool_size))
        dmax[np.arange(self.arg_max.size), self.arg_max.flatten()] = dout.flatten()
        dmax = dmax.reshape(dout.shape + (pool_size,)) 
        
        dcol = dmax.reshape(dmax.shape[0] * dmax.shape[1] * dmax.shape[2], -1)
        dx = col2im(dcol, self.x.shape, self.pool_h, self.pool_w, self.stride, self.pad)
        
        return dx

# %% [markdown]
# ## sinple convolution network class

# %%
class SimpleConvNet:
    # conv - relu - pool - affine - relu - affine - softmax
    def __init__(self, input_dim=(1, 28, 28), conv_param={'filter_num':30, 'filter_size':5, 'pad':0, 'stride':1},
                 hidden_size=100, output_size=10, weight_init_std=0.01):
        filter_num = conv_param['filter_num']        
        filter_size = conv_param['filter_size']
        filter_pad = conv_param['pad']
        filter_stride = conv_param['stride']
        input_size = input_dim[1]
        conv_output_size = (input_size - filter_size + 2 * filter_pad) / filter_stride + 1
        pool_output_size = int(filter_num * (conv_output_size / 2) * (conv_output_size / 2))

        # 重みの初期化
        self.params = {}
        self.params['W1'] = weight_init_std * np.random.randn(filter_num, input_dim[0], filter_size, filter_size)
        self.params['b1'] = np.zeros(filter_num)
        self.params['W2'] = weight_init_std * np.random.randn(pool_output_size, hidden_size)
        self.params['b2'] = np.zeros(hidden_size)
        self.params['W3'] = weight_init_std * np.random.randn(hidden_size, output_size)
        self.params['b3'] = np.zeros(output_size)

        # レイヤの生成
        self.layers = OrderedDict()
        self.layers['Conv1'] = layers.Convolution(self.params['W1'], self.params['b1'], conv_param['stride'], conv_param['pad'])
        self.layers['Relu1'] = layers.Relu()
        self.layers['Pool1'] = layers.Pooling(pool_h=2, pool_w=2, stride=2)
        self.layers['Affine1'] = layers.Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = layers.Relu()
        self.layers['Affine2'] = layers.Affine(self.params['W3'], self.params['b3'])

        self.last_layer = layers.SoftmaxWithLoss()

    def predict(self, x):
        for key in self.layers.keys():
            x = self.layers[key].forward(x)
        return x
        
    def loss(self, x, d):
        y = self.predict(x)
        return self.last_layer.forward(y, d)

    def accuracy(self, x, d, batch_size=100):
        if d.ndim != 1 : d = np.argmax(d, axis=1)
        
        acc = 0.0
        
        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            td = d[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == td) 
        
        return acc / x.shape[0]

    def gradient(self, x, d):
        # forward
        self.loss(x, d)
        
        # backward
        dout = 1
        dout = self.last_layer.backward(dout)
        layers = list(self.layers.values())
        
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        grad['W1'], grad['b1'] = self.layers['Conv1'].dW, self.layers['Conv1'].db
        grad['W2'], grad['b2'] = self.layers['Affine1'].dW, self.layers['Affine1'].db
        grad['W3'], grad['b3'] = self.layers['Affine2'].dW, self.layers['Affine2'].db

        return grad

# %%
from common import optimizer

# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

print("データ読み込み完了")

# 処理に時間のかかる場合はデータを削減 
x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]


network = SimpleConvNet(input_dim=(1,28,28), conv_param = {'filter_num': 30, 'filter_size': 5, 'pad': 0, 'stride': 1},
                        hidden_size=100, output_size=10, weight_init_std=0.01)

optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10



for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)

    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.5308
#                 : 10. 正答率(テスト) = 0.497
# Generation: 20. 正答率(トレーニング) = 0.6774
#                 : 20. 正答率(テスト) = 0.614
# Generation: 30. 正答率(トレーニング) = 0.7328
#                 : 30. 正答率(テスト) = 0.701
# Generation: 40. 正答率(トレーニング) = 0.7822
#                 : 40. 正答率(テスト) = 0.74
# Generation: 50. 正答率(トレーニング) = 0.845
#                 : 50. 正答率(テスト) = 0.793
# Generation: 60. 正答率(トレーニング) = 0.86
#                 : 60. 正答率(テスト) = 0.831
# Generation: 70. 正答率(トレーニング) = 0.878
#                 : 70. 正答率(テスト) = 0.853
# Generation: 80. 正答率(トレーニング) = 0.8876
#                 : 80. 正答率(テスト) = 0.854
# Generation: 90. 正答率(トレーニング) = 0.8786
#                 : 90. 正答率(テスト) = 0.847
# Generation: 100. 正答率(トレーニング) = 0.8866
#                 : 100. 正答率(テスト) = 0.85
# Generation: 110. 正答率(トレーニング) = 0.8988
#                 : 110. 正答率(テスト) = 0.877
# Generation: 120. 正答率(トレーニング) = 0.8978
#                 : 120. 正答率(テスト) = 0.873
# Generation: 130. 正答率(トレーニング) = 0.9068
#                 : 130. 正答率(テスト) = 0.877
# Generation: 140. 正答率(トレーニング) = 0.9146
#                 : 140. 正答率(テスト) = 0.877
# Generation: 150. 正答率(トレーニング) = 0.9166
#                 : 150. 正答率(テスト) = 0.889
# Generation: 160. 正答率(トレーニング) = 0.9246
#                 : 160. 正答率(テスト) = 0.895
# Generation: 170. 正答率(トレーニング) = 0.9162
#                 : 170. 正答率(テスト) = 0.888
# Generation: 180. 正答率(トレーニング) = 0.9206
#                 : 180. 正答率(テスト) = 0.898
# Generation: 190. 正答率(トレーニング) = 0.9232
#                 : 190. 正答率(テスト) = 0.897
# Generation: 200. 正答率(トレーニング) = 0.9252
#                 : 200. 正答率(テスト) = 0.892
# Generation: 210. 正答率(トレーニング) = 0.9246
#                 : 210. 正答率(テスト) = 0.905
# Generation: 220. 正答率(トレーニング) = 0.9328
#                 : 220. 正答率(テスト) = 0.904
# Generation: 230. 正答率(トレーニング) = 0.9346
#                 : 230. 正答率(テスト) = 0.901
# Generation: 240. 正答率(トレーニング) = 0.9384
#                 : 240. 正答率(テスト) = 0.903
# Generation: 250. 正答率(トレーニング) = 0.945
#                 : 250. 正答率(テスト) = 0.913
# Generation: 260. 正答率(トレーニング) = 0.9466
#                 : 260. 正答率(テスト) = 0.915
# Generation: 270. 正答率(トレーニング) = 0.9436
#                 : 270. 正答率(テスト) = 0.915
# Generation: 280. 正答率(トレーニング) = 0.9494
#                 : 280. 正答率(テスト) = 0.913
# Generation: 290. 正答率(トレーニング) = 0.9478
#                 : 290. 正答率(テスト) = 0.918
# Generation: 300. 正答率(トレーニング) = 0.9482
#                 : 300. 正答率(テスト) = 0.918
# Generation: 310. 正答率(トレーニング) = 0.952
#                 : 310. 正答率(テスト) = 0.919
# Generation: 320. 正答率(トレーニング) = 0.9484
#                 : 320. 正答率(テスト) = 0.911
# Generation: 330. 正答率(トレーニング) = 0.9542
#                 : 330. 正答率(テスト) = 0.932
# Generation: 340. 正答率(トレーニング) = 0.9592
#                 : 340. 正答率(テスト) = 0.933
# Generation: 350. 正答率(トレーニング) = 0.9598
#                 : 350. 正答率(テスト) = 0.934
# Generation: 360. 正答率(トレーニング) = 0.9604
#                 : 360. 正答率(テスト) = 0.936
# Generation: 370. 正答率(トレーニング) = 0.9638
#                 : 370. 正答率(テスト) = 0.937
# Generation: 380. 正答率(トレーニング) = 0.963
#                 : 380. 正答率(テスト) = 0.933
# Generation: 390. 正答率(トレーニング) = 0.9662
#                 : 390. 正答率(テスト) = 0.934
# Generation: 400. 正答率(トレーニング) = 0.9646
#                 : 400. 正答率(テスト) = 0.938
# Generation: 410. 正答率(トレーニング) = 0.9676
#                 : 410. 正答率(テスト) = 0.942
# Generation: 420. 正答率(トレーニング) = 0.9668
#                 : 420. 正答率(テスト) = 0.94
# Generation: 430. 正答率(トレーニング) = 0.9622
#                 : 430. 正答率(テスト) = 0.935
# Generation: 440. 正答率(トレーニング) = 0.969
#                 : 440. 正答率(テスト) = 0.934
# Generation: 450. 正答率(トレーニング) = 0.9728
#                 : 450. 正答率(テスト) = 0.94
# Generation: 460. 正答率(トレーニング) = 0.9738
#                 : 460. 正答率(テスト) = 0.947
# Generation: 470. 正答率(トレーニング) = 0.975
#                 : 470. 正答率(テスト) = 0.948
# Generation: 480. 正答率(トレーニング) = 0.9732
#                 : 480. 正答率(テスト) = 0.937
# Generation: 490. 正答率(トレーニング) = 0.9704
#                 : 490. 正答率(テスト) = 0.94
# Generation: 500. 正答率(トレーニング) = 0.9744
#                 : 500. 正答率(テスト) = 0.941
# Generation: 510. 正答率(トレーニング) = 0.976
#                 : 510. 正答率(テスト) = 0.94
# Generation: 520. 正答率(トレーニング) = 0.9726
#                 : 520. 正答率(テスト) = 0.94
# Generation: 530. 正答率(トレーニング) = 0.9772
#                 : 530. 正答率(テスト) = 0.946
# Generation: 540. 正答率(トレーニング) = 0.9804
#                 : 540. 正答率(テスト) = 0.951
# Generation: 550. 正答率(トレーニング) = 0.9806
#                 : 550. 正答率(テスト) = 0.953
# Generation: 560. 正答率(トレーニング) = 0.9794
#                 : 560. 正答率(テスト) = 0.941
# Generation: 570. 正答率(トレーニング) = 0.9812
#                 : 570. 正答率(テスト) = 0.95
# Generation: 580. 正答率(トレーニング) = 0.9822
#                 : 580. 正答率(テスト) = 0.948
# Generation: 590. 正答率(トレーニング) = 0.9832
#                 : 590. 正答率(テスト) = 0.95
# Generation: 600. 正答率(トレーニング) = 0.9858
#                 : 600. 正答率(テスト) = 0.947
# Generation: 610. 正答率(トレーニング) = 0.9834
#                 : 610. 正答率(テスト) = 0.95
# Generation: 620. 正答率(トレーニング) = 0.984
#                 : 620. 正答率(テスト) = 0.953
# Generation: 630. 正答率(トレーニング) = 0.9854
#                 : 630. 正答率(テスト) = 0.948
# Generation: 640. 正答率(トレーニング) = 0.9838
#                 : 640. 正答率(テスト) = 0.95
# Generation: 650. 正答率(トレーニング) = 0.9826
#                 : 650. 正答率(テスト) = 0.944
# Generation: 660. 正答率(トレーニング) = 0.9872
#                 : 660. 正答率(テスト) = 0.948
# Generation: 670. 正答率(トレーニング) = 0.9818
#                 : 670. 正答率(テスト) = 0.948
# Generation: 680. 正答率(トレーニング) = 0.9822
#                 : 680. 正答率(テスト) = 0.945
# Generation: 690. 正答率(トレーニング) = 0.9818
#                 : 690. 正答率(テスト) = 0.94
# Generation: 700. 正答率(トレーニング) = 0.9852
#                 : 700. 正答率(テスト) = 0.946
# Generation: 710. 正答率(トレーニング) = 0.9868
#                 : 710. 正答率(テスト) = 0.95
# Generation: 720. 正答率(トレーニング) = 0.9868
#                 : 720. 正答率(テスト) = 0.949
# Generation: 730. 正答率(トレーニング) = 0.9858
#                 : 730. 正答率(テスト) = 0.947
# Generation: 740. 正答率(トレーニング) = 0.9872
#                 : 740. 正答率(テスト) = 0.948
# Generation: 750. 正答率(トレーニング) = 0.9864
#                 : 750. 正答率(テスト) = 0.941
# Generation: 760. 正答率(トレーニング) = 0.9836
#                 : 760. 正答率(テスト) = 0.95
# Generation: 770. 正答率(トレーニング) = 0.9836
#                 : 770. 正答率(テスト) = 0.949
# Generation: 780. 正答率(トレーニング) = 0.9876
#                 : 780. 正答率(テスト) = 0.952
# Generation: 790. 正答率(トレーニング) = 0.9904
#                 : 790. 正答率(テスト) = 0.957
# Generation: 800. 正答率(トレーニング) = 0.9874
#                 : 800. 正答率(テスト) = 0.954
# Generation: 810. 正答率(トレーニング) = 0.9874
#                 : 810. 正答率(テスト) = 0.955
# Generation: 820. 正答率(トレーニング) = 0.9902
#                 : 820. 正答率(テスト) = 0.955
# Generation: 830. 正答率(トレーニング) = 0.99
#                 : 830. 正答率(テスト) = 0.95
# Generation: 840. 正答率(トレーニング) = 0.9914
#                 : 840. 正答率(テスト) = 0.947
# Generation: 850. 正答率(トレーニング) = 0.9922
#                 : 850. 正答率(テスト) = 0.955
# Generation: 860. 正答率(トレーニング) = 0.9902
#                 : 860. 正答率(テスト) = 0.957
# Generation: 870. 正答率(トレーニング) = 0.9914
#                 : 870. 正答率(テスト) = 0.953
# Generation: 880. 正答率(トレーニング) = 0.9916
#                 : 880. 正答率(テスト) = 0.957
# Generation: 890. 正答率(トレーニング) = 0.992
#                 : 890. 正答率(テスト) = 0.95
# Generation: 900. 正答率(トレーニング) = 0.9954
#                 : 900. 正答率(テスト) = 0.954
# Generation: 910. 正答率(トレーニング) = 0.995
#                 : 910. 正答率(テスト) = 0.959
# Generation: 920. 正答率(トレーニング) = 0.9944
#                 : 920. 正答率(テスト) = 0.952
# Generation: 930. 正答率(トレーニング) = 0.9934
#                 : 930. 正答率(テスト) = 0.952
# Generation: 940. 正答率(トレーニング) = 0.9958
#                 : 940. 正答率(テスト) = 0.958
# Generation: 950. 正答率(トレーニング) = 0.9954
#                 : 950. 正答率(テスト) = 0.958
# Generation: 960. 正答率(トレーニング) = 0.9948
#                 : 960. 正答率(テスト) = 0.96
# Generation: 970. 正答率(トレーニング) = 0.9958
#                 : 970. 正答率(テスト) = 0.96
# Generation: 980. 正答率(トレーニング) = 0.9964
#                 : 980. 正答率(テスト) = 0.96
# Generation: 990. 正答率(トレーニング) = 0.9954
#                 : 990. 正答率(テスト) = 0.957
# Generation: 1000. 正答率(トレーニング) = 0.9958
#                 : 1000. 正答率(テスト) = 0.956
